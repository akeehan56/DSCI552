# %% [markdown]
# <center><h1>Keehan_Alyssa_HW1</h1></center>
# <br>
# <center><font size="4">Vertebral Column Data</font></center>
#
# **Name:** Alyssa Keehan
# **GitHub Username:** akeehan56
# **Email:** akeehan@usc.edu
# **USC ID:** 3429542433

# %% [markdown]
# ### (a) Download Data

# %% [markdown]
# Package imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Get the Vertebral Column Data Set

# %%
column_names = [
    "pelvic_incidence",
    "pelvic_tilt",
    "lumbar_lordosis_angle",
    "sacral_slope",
    "pelvic_radius",
    "grade_spondylolisthesis",
    "class"
]

data = pd.read_csv(
    "../data/vertebral_column_data/column_2C.dat",
    sep=r"\s+",
    header=None,
    names=column_names
)

data.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0             63.03        22.55                  39.61         40.48
# 1             39.06        10.06                  25.02         29.00
# 2             68.83        22.22                  50.09         46.61
# 3             69.30        24.65                  44.31         44.64
# 4             49.71         9.65                  28.32         40.06
#
#    pelvic_radius  grade_spondylolisthesis class
# 0          98.67                    -0.25    AB
# 1         114.41                     4.56    AB
# 2         105.99                    -3.53    AB
# 3         101.87                    11.21    AB
# 4         108.17                     7.92    AB

# %% [markdown]
# ### (b) Pre-Processing and Exploratory Data Analysis

# %% [markdown]
# #### i. Scatterplots

# %% [markdown]
# #### ii. Boxplots

# %% [markdown]
# #### iii. Split Data Set

# %% [markdown]
# ### (c) Classification

# %% [markdown]
# #### i. Euclidean Metric

# %% [markdown]
# #### ii. Test Data

# %% [markdown]
# #### iii. Learning Curve

# %% [markdown]
# ### (d) Other Metrics

# %% [markdown]
# #### i. Minkowski Distance.

# %% [markdown]
# ##### A. Manhattan Distance with p = 1.

# %% [markdown]
# ##### B. With log10(p) in {0.1, 0.2, 0.3, ... ,1}.

# %% [markdown]
# ##### C. Chebyshev Distance With p -> infinity.

# %% [markdown]
# #### ii. Mahalanobis Distance.

# %% [markdown]
# ### (e) Weighted Decision

# %% [markdown]
# ### (f) Training Error Rate
